# %% [markdown]
# ## 深度循环神经网络
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
import torch
from torch import nn
import dltools

# %%
batch_size, num_steps = 32, 35
train_iter, vocab = dltools.load_data_time_machine(batch_size, num_steps)

# %%
vocab_size, num_hiddens, num_layers = len(vocab), 256, 2
num_inputs = vocab_size
device = dltools.try_gpu()
rnn_layer = nn.RNN(num_inputs, num_hiddens, num_layers)
model = dltools.RNNModel(rnn_layer, len(vocab))
model = model.to(device)

# %%
# 双层隐藏层的循环神经网络 训练和预测
num_epochs, lr = 500, 1
dltools.train_ch8(model, train_iter, vocab, lr, num_epochs, device)
# Out:
# perplexity 1.1, 230357.4 tokens/sec on cuda:0
# time traveller but now you begin to seethe object of my investig
# traveller but now you begin to seethe object of my investig

# %%
lstm_layer = nn.LSTM(num_inputs, num_hiddens, num_layers)
model = dltools.RNNModel(lstm_layer, len(vocab))
model = model.to(device)
dltools.train_ch8(model, train_iter, vocab, lr, num_epochs, device)
# Out:
# perplexity 1.1, 116674.8 tokens/sec on cuda:0
# time traveller for so it will be convenient to speak of himwas e
# traveller with a slight accession ofcheerfulness really thi

# %%
gru_layer = nn.LSTM(num_inputs, num_hiddens, num_layers)
model = dltools.RNNModel(gru_layer, len(vocab))
model = model.to(device)
dltools.train_ch8(model, train_iter, vocab, lr, num_epochs, device)
# Out:
# perplexity 1.1, 112299.3 tokens/sec on cuda:0
# time traveller wot n shis been at work upon thisgeometry of four
# traveller with a slight accession ofcheerfulness really thi
